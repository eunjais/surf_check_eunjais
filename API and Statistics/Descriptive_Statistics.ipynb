# %%
#Import
# Import the requests library.
import requests
import pandas as pd
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the API key.
from config import key

# %%
#Open CSV
final_beach_df = pd.read_csv("Resources/final_beach_data.csv")
final_beach_df
# Out:
#      Beach_ID                          Beach_Name   Latitude   Longitude  \
# 0           0             Border Field State Park  32.544940 -117.122341
# 1           1                 Pelican State Beach  41.992395 -124.209664
# 2           2                      Crescent Beach  41.728363 -124.153178
# 3           3               Redwood National Park  41.208970 -124.119056
# 4           4  Prairie Creek Redwoods State Beach  41.401741 -124.041649
# ..        ...                                 ...        ...         ...
# 247       247                       Mission Beach  32.773040 -117.251710
# 248       248              Ocean Beach City Beach  32.741633 -117.254458
# 249       249            Coronado Municipal Beach  32.689464 -117.186835
# 250       250           Silver Strand State Beach  32.634664 -117.141993
# 251       251                      Imperial Beach  32.575831 -117.126577
#
#      Sunrise   Sunset   Weather_Description  Temperature  Water_Temperature  \
# 0    7:07 AM  5:57 PM  Patchy rain possible           62                 67
# 1    7:52 AM  6:09 PM     Light rain shower           48                 52
# 2    7:51 AM  6:10 PM     Light rain shower           46                 52
# 3    7:49 AM  6:11 PM  Patchy rain possible           47                 53
# 4    7:49 AM  6:11 PM  Patchy rain possible           47                 53
# ..       ...      ...                   ...          ...                ...
# 247  7:08 AM  5:57 PM  Patchy rain possible           62                 68
# 248  7:08 AM  5:57 PM  Patchy rain possible           62                 68
# 249  7:07 AM  5:57 PM  Patchy rain possible           62                 67
# 250  7:07 AM  5:57 PM  Patchy rain possible           62                 67
# 251  7:07 AM  5:57 PM  Patchy rain possible           62                 67
#
#      Cloud_Cover  Wind_Speed  Wave_Height
# 0             70          12          3.0
# 1            100           4         10.5
# 2            100           6          7.9
# 3             86           7          9.5
# 4             86           7          9.5
# ..           ...         ...          ...
# 247           76          11          2.6
# 248           76          11          2.6
# 249           76          12          3.0
# 250           73          12          3.0
# 251           73          12          3.0
#
# [252 rows x 12 columns]

# %%
### BY WAVE HEIGHT

# %%
#New DF for wave height
wave_height_df = final_beach_df[["Beach_Name", "Wave_Height"]].copy()
wave_height_df
# Out:
#                              Beach_Name  Wave_Height
# 0               Border Field State Park          3.0
# 1                   Pelican State Beach         10.5
# 2                        Crescent Beach          7.9
# 3                 Redwood National Park          9.5
# 4    Prairie Creek Redwoods State Beach          9.5
# ..                                  ...          ...
# 247                       Mission Beach          2.6
# 248              Ocean Beach City Beach          2.6
# 249            Coronado Municipal Beach          3.0
# 250           Silver Strand State Beach          3.0
# 251                      Imperial Beach          3.0
#
# [252 rows x 2 columns]

# %%
wave_height_df.describe()
# Out:
#        Wave_Height
# count   252.000000
# mean      3.989683
# std       2.264461
# min       0.700000
# 25%       2.300000
# 50%       2.600000
# 75%       5.900000
# max      10.500000

# %%
# Flatten column MultiIndex
wave_height_df.columns = [x[0] for x in wave_height_df.columns]

# %%
wave_height_bins = [0, 3, 9, 12]
wave_sizes = ["Small (<4)", "Medium (4-9)", "Large (10-12)"]


# Categorize based on the bins.
final_beach_df["Wave Size"] = pd.cut(final_beach_df["Wave_Height"], wave_height_bins, labels=wave_sizes)
final_beach_df
# Out:
#      Beach_ID                          Beach_Name   Latitude   Longitude  \
# 0           0             Border Field State Park  32.544940 -117.122341
# 1           1                 Pelican State Beach  41.992395 -124.209664
# 2           2                      Crescent Beach  41.728363 -124.153178
# 3           3               Redwood National Park  41.208970 -124.119056
# 4           4  Prairie Creek Redwoods State Beach  41.401741 -124.041649
# ..        ...                                 ...        ...         ...
# 247       247                       Mission Beach  32.773040 -117.251710
# 248       248              Ocean Beach City Beach  32.741633 -117.254458
# 249       249            Coronado Municipal Beach  32.689464 -117.186835
# 250       250           Silver Strand State Beach  32.634664 -117.141993
# 251       251                      Imperial Beach  32.575831 -117.126577
#
#      Sunrise   Sunset   Weather_Description  Temperature  Water_Temperature  \
# 0    7:07 AM  5:57 PM  Patchy rain possible           62                 67
# 1    7:52 AM  6:09 PM     Light rain shower           48                 52
# 2    7:51 AM  6:10 PM     Light rain shower           46                 52
# 3    7:49 AM  6:11 PM  Patchy rain possible           47                 53
# 4    7:49 AM  6:11 PM  Patchy rain possible           47                 53
# ..       ...      ...                   ...          ...                ...
# 247  7:08 AM  5:57 PM  Patchy rain possible           62                 68
# 248  7:08 AM  5:57 PM  Patchy rain possible           62                 68
# 249  7:07 AM  5:57 PM  Patchy rain possible           62                 67
# 250  7:07 AM  5:57 PM  Patchy rain possible           62                 67
# 251  7:07 AM  5:57 PM  Patchy rain possible           62                 67
#
#      Cloud_Cover  Wind_Speed  Wave_Height      Wave Size
# 0             70          12          3.0     Small (<4)
# 1            100           4         10.5  Large (10-12)
# 2            100           6          7.9   Medium (4-9)
# 3             86           7          9.5  Large (10-12)
# 4             86           7          9.5  Large (10-12)
# ..           ...         ...          ...            ...
# 247           76          11          2.6     Small (<4)
# 248           76          11          2.6     Small (<4)
# 249           76          12          3.0     Small (<4)
# 250           73          12          3.0     Small (<4)
# 251           73          12          3.0     Small (<4)
#
# [252 rows x 13 columns]

# %%
###DESCRIBE

# %%
final_beach_df["Water_Temperature"].mean()
# Out:
# 59.98412698412698

# %%
final_beach_df["Temperature"].mean()
# Out:
# 56.30555555555556

# %%
final_beach_df["Cloud_Cover"].mean()
# Out:
# 62.638888888888886
