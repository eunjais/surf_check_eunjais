# %%
# Import the requests library.
import requests
from citipy import citipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
import json as js

# Import the API key.
from config import api_key

# %%
beaches_df = pd.read_csv("ca_beaches.csv")
beaches_df.head()
# Out:
#    beach_id                beach_name   latitude   longitude
# 0         1       Pelican State Beach  41.992395 -124.209664
# 1         2            Crescent Beach  41.728363 -124.153178
# 2         3        Sue-meg State Park  41.136653 -124.155297
# 3         4      Trinidad State Beach  41.065822 -124.149789
# 4         5  Little River State Beach  41.016880 -124.111753

# %%
beaches_df.dtypes
# Out:
# beach_id        int64
# beach_name     object
# latitude      float64
# longitude     float64
# dtype: object

# %%
# Renamed "Unnamed: 0" column and set it as the index
beaches_df = beaches_df.rename(columns={'Unnamed: 0': ''})
beaches_df = beaches_df.set_index('beach_id')
beaches_df.head()
# Out:
#                         beach_name   latitude   longitude
# beach_id
# 1              Pelican State Beach  41.992395 -124.209664
# 2                   Crescent Beach  41.728363 -124.153178
# 3               Sue-meg State Park  41.136653 -124.155297
# 4             Trinidad State Beach  41.065822 -124.149789
# 5         Little River State Beach  41.016880 -124.111753

# %%
#beaches_df = beaches_df.drop_duplicates(keep='first')
#beaches_df

# %%
# Create the output file (CSV).
#output_data_file = "ck_beaches.csv"

# Export the beaches_df into a CSV.
#beaches_df.to_csv(output_data_file, index_label="beach_id")

# %%
# Create a set of latitude and longitude combinations.
beach = beaches_df['beach_name']
lats = beaches_df['latitude']
lngs = beaches_df['longitude']

beaches_lat_lngs = zip(beach, lats, lngs)
coordinates = list(beaches_lat_lngs)

for coordinate in coordinates:
    print(coordinate[0], coordinate[1], coordinate[2])
# Out:
# Pelican State Beach 41.992395 -124.209664
# Crescent Beach 41.72836258 -124.1531784
# Sue-meg State Park 41.13665293 -124.155297
# Trinidad State Beach 41.06582175 -124.1497893
# Little River State Beach 41.01688007 -124.1117529
# Clam Beach County Park 40.99847401 -124.1151808
# Clam Beach 40.99536694 -124.1109588
# Sinkyone Wilderness State Park 39.92043479 -123.9397125
# Westport-Union Landing State Beach 39.67716307 -123.7912683
# MacKerricher Beach 39.489781 -123.798271
# Glass Beach 39.45277476 -123.8133215
# Caspar Beach 39.3627382 -123.8172252
# Mendocino Headlands State Park 39.309033 -123.806658
# Manchester State Park 38.98385949 -123.6993187
# Schooner Gulch State Beach 38.86821949 -123.6547063
# Gualala Point Regional Park 38.76076189 -123.526723
# Black Point Beach 38.686409 -123.432347
# Goat Rock Beach 38.44711794 -123.1265214
# Blind Beach 38.43699972 -123.1223772
# Shell Beach 38.417464 -123.105601
# Wrights Beach 38.40033248 -123.0969266
# Gleason Beach 38.39010789 -123.0857298
# Schoolhouse Beach 38.37626954 -123.0786946
# Carmet Beach 38.37254912 -123.0762862
# Arched Rock Beach 38.36725878 -123.0726081
# Coleman Beach 38.36596694 -123.0714996
# Miwok Beach 38.36111029 -123.0691915
# North Salmon Creek Beach 38.35991175 -123.0687585
# South Salmon Creek Beach 38.33989879 -123.0684011
# Doran Beach 38.31450636 -123.0443867
# Dillon beach 38.25058272 -122.9669146
# West Street Beach 33.50595903 -117.7486526
# 1,000 Steps Beach 33.4985416 -117.7414247
# Salt Creek County Beach 33.47769283 -117.7226023
# Doheny State Beach 33.46287214 -117.6873259
# Capistrano Beach Park 33.45614113 -117.6676277
# Beach State Park 33.45460429 -117.6692246
# Poche Beach 33.44156743 -117.64617
# San Clemente City Beach 33.42782296 -117.6280388
# San Clemente State Beach 33.40365884 -117.6048362
# San Onofre State Beach 33.37388206 -117.5662879
# Del Mar Beach, Camp Pendleton 33.22066881 -117.4072513
# Oceanside Harbor Beach 33.204828 -117.394755
# Oceanside City Beach 33.19538512 -117.3857032
# Buccaneer Beach, Oceanside 33.17851501 -117.3703371
# South Oceanside Beach (Cassidy Street) 33.17311454 -117.3655589
# Saint Malo Beach 33.16615726 -117.360099
# Carlsbad City Beach 33.15757212 -117.3532021
# Carlsbad State Beach 33.15031883 -117.3487623
# Terra Mar Point 33.12822917 -117.3335735
# Ponto Beach 33.10747125 -117.3218329
# South Carlsbad State Beach 33.10359124 -117.3199447
# Grandview 33.07705649 -117.3110183
# Beacon's Beach 33.07691959 -117.3099082
# Stone Steps Beach 33.05364974 -117.3011103
# Moonlight Beach 33.0493509 -117.298868
# D Street Viewpoint 33.04570416 -117.2974281
# Swamis 33.03502813 -117.2929205
# San Elijo State Beach 33.02257902 -117.2842516
# Cardiff State Beach 33.01050606 -117.27963
# Tide Beach Park 32.99686572 -117.2764543
# Fletcher Cove Park 32.99089067 -117.2752956
# Seascape Surf 32.98567586 -117.2729118
# Del Mar City Beach 32.97695929 -117.269502
# Torrey Pines State Beach 32.93778126 -117.2617343
# Black's Beach 32.89147257 -117.2559886
# La Jolla Shores 32.88563453 -117.2535424
# La Jolla Cove 32.85038249 -117.2730244
# Marine Street Beach 32.83785649 -117.2816841
# Windansea Beach 32.83123002 -117.2813634
# Tourmaline Surfing Park 32.80545903 -117.2625367
# Pacific Beach 32.79393428 -117.2568115
# Mission Beach 32.77304026 -117.25171
# Ocean Beach City Beach 32.74163262 -117.2544577
# Coronado Municipal Beach 32.68946424 -117.1868348
# Silver Strand State Beach 32.63466425 -117.1419929
# Imperial Beach 32.57583119 -117.1265769

# %%
print(coordinates[180])
# Out:
# ('Grandview', 33.07705649, -117.3110183)

# %%
len(beach)
# Out:
# 205

# %%
# Starting URL for Weather Map API Call.
url = 'http://api.worldweatheronline.com/premium/v1/marine.ashx?key=' + api_key 
print(url)
# Out:
# http://api.worldweatheronline.com/premium/v1/marine.ashx?key=1d33ea93dff947868fd183328222411

# %%
# Create an endpoint URL for a beach.
lat = 33.07705649
long = -117.3110183
beach_url = url + "&format=json&q=" + str(lat) + "," + str(long)
print(beach_url)

#api.openweathermap.org/data/2.5/forecast/daily?lat={lat}&lon={lon}&cnt={cnt}&appid={API key}
# Out:
# http://api.worldweatheronline.com/premium/v1/marine.ashx?key=1d33ea93dff947868fd183328222411&format=json&q=33.07705649,-117.3110183

# %%
# Create an endpoint URL for a beach.
beach = "Grandview"
beach_url = url + "&format=json&q=" + str(lat) + "," + str(long)
print(beach_url)

#api.openweathermap.org/data/2.5/forecast/daily?lat={lat}&lon={lon}&cnt={cnt}&appid={API key}
# Out:
# http://api.worldweatheronline.com/premium/v1/marine.ashx?key=1d33ea93dff947868fd183328222411&format=json&q=33.07705649,-117.3110183

# %%
#for i, beach in enumerate(coordinates):
#    beach_url = url + "&format=json&q=" + str(coordinates[i-1][1]) + "," + str(coordinates[i-1][2])
#    beach_weather = requests.get(beach_url).json()
#    
#    sunrise = beaches_df['data']['weather'][0]['astronomy'][0]['sunrise']    
#    print(sunrise)

# %%
# test lat and long variables which are going to be beach coordinates
## using Grandview Coordinates= 33.07705649, -117.3110183
lat = 33.07705649
long = -117.3110183

# Create an endpoint URL for a beach. 

beach_url = url + "&format=json&q=" + str(lat) + "," + str(long)

#get it in text format
beach_weather = requests.get(beach_url)

if beach_weather.status_code == 200:
    print (f"Beach Weather found.")

else: 
    print (f"Beach weather not found.")
# Out:
# Beach Weather found.

# %%
# Create an empty list to hold the weather data.
beach_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the beaches in the list.
for i, j in enumerate(coordinates) :

    # Group beaches in sets of 30 for logging purposes.
    if (i % 30 == 0 and i >= 30):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each beach.
    beach_url = url + "&format=json&q=" + str(coordinates[i-1][1]) + "," + str(coordinates[i-1][2])

    # Log the URL, record, and set numbers and the beach.
    print(f"Processing Record {record_count} of Set {set_count} --- {coordinates[i-1][0]}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each beach.
    try:
        # Parse the JSON and retrieve data.
        beach_weather = requests.get(beach_url).json()
        
        # Parse out the needed data.
        sunrise = beach_weather['data']['weather'][0]['astronomy'][0]['sunrise']
        sunset = beach_weather['data']['weather'][0]['astronomy'][0]['sunset']
        weather = beach_weather['data']['weather'][0]['hourly'][2]['weatherDesc'][0]['value']
        temp = beach_weather['data']['weather'][0]['hourly'][2]['tempF']
        watertemp = beach_weather['data']['weather'][0]['hourly'][2]['waterTemp_F']
        cloudcover = beach_weather['data']['weather'][0]['hourly'][2]['cloudcover']
        windspeed = beach_weather['data']['weather'][0]['hourly'][2]['windspeedMiles']
        swell = beach_weather['data']['weather'][0]['hourly'][2]['swellHeight_ft']
        
        # Append the beach information into beach_data list.
        beach_data.append({"Beach_Name": coordinates [i-1][0],
                           "Latitude": coordinates [i-1][1],
                           "Longitude": coordinates [i-1][2],
                          "Sunrise": sunrise,
                          "Sunset": sunset,
                          "Weather_Description": weather,
                          "Temperature": temp,
                          "Water_Temperature": watertemp,
                          "Cloud_Cover": cloudcover,
                          "Wind_Speed": windspeed,
                          "Wave_Height": swell
                         })

# If an error is experienced, skip the beach.
    except:
        print("Beach information not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 --- Imperial Beach
# Processing Record 2 of Set 1 --- Pelican State Beach
# Processing Record 3 of Set 1 --- Crescent Beach
# Processing Record 4 of Set 1 --- Sue-meg State Park
# Processing Record 5 of Set 1 --- Trinidad State Beach
# Processing Record 6 of Set 1 --- Little River State Beach
# Processing Record 7 of Set 1 --- Clam Beach County Park
# Processing Record 8 of Set 1 --- Clam Beach
# Processing Record 9 of Set 1 --- Sinkyone Wilderness State Park
# Processing Record 10 of Set 1 --- Westport-Union Landing State Beach
# Processing Record 11 of Set 1 --- MacKerricher Beach
# Processing Record 12 of Set 1 --- Glass Beach
# Processing Record 13 of Set 1 --- Caspar Beach
# Processing Record 14 of Set 1 --- Mendocino Headlands State Park
# Processing Record 15 of Set 1 --- Manchester State Park
# Processing Record 16 of Set 1 --- Schooner Gulch State Beach
# Processing Record 17 of Set 1 --- Gualala Point Regional Park
# Processing Record 18 of Set 1 --- Black Point Beach
# Processing Record 19 of Set 1 --- Goat Rock Beach
# Processing Record 20 of Set 1 --- Blind Beach
# Processing Record 21 of Set 1 --- Shell Beach
# Processing Record 22 of Set 1 --- Wrights Beach
# Processing Record 23 of Set 1 --- Gleason Beach
# Processing Record 24 of Set 1 --- Schoolhouse Beach
# Processing Record 25 of Set 1 --- Carmet Beach
# Processing Record 26 of Set 1 --- Arched Rock Beach
# Processing Record 27 of Set 1 --- Coleman Beach
# Processing Record 28 of Set 1 --- Miwok Beach
# Processing Record 29 of Set 1 --- North Salmon Creek Beach
# Processing Record 30 of Set 1 --- South Salmon Creek Beach
# Processing Record 1 of Set 2 --- Doran Beach
# Processing Record 2 of Set 2 --- Dillon beach
# Processing Record 3 of Set 2 --- Point Reyes Beach
# Processing Record 4 of Set 2 --- Stinson Beach Park
# Processing Record 5 of Set 2 --- Muir Beach
# Processing Record 6 of Set 2 --- Rodeo Beach
# Processing Record 7 of Set 2 --- Marshall's Beach
# Processing Record 8 of Set 2 --- Baker Beach
# Processing Record 9 of Set 2 --- Lands End Beach
# Processing Record 10 of Set 2 --- Ocean Beach (SF)
# Processing Record 11 of Set 2 --- Funston Beach
# Processing Record 12 of Set 2 --- Thornton Beach State Park
# Processing Record 13 of Set 2 --- Mussel Rock Park
# Processing Record 14 of Set 2 --- Gray Whale Cove State Beach
# Processing Record 15 of Set 2 --- Montara State Beach
# Processing Record 16 of Set 2 --- El Granada Beach
# Processing Record 17 of Set 2 --- Vallejo Beach
# Processing Record 18 of Set 2 --- Roosevelt Beach
# Processing Record 19 of Set 2 --- Dunes Beach
# Processing Record 20 of Set 2 --- Half Moon Bay State Beach
# Processing Record 21 of Set 2 --- Francis Beach
# Processing Record 22 of Set 2 --- Poplar Beach
# Processing Record 23 of Set 2 --- Redondo State Beach
# Processing Record 24 of Set 2 --- Cowell Ranch Beach
# Processing Record 25 of Set 2 --- Martins Beach
# Processing Record 26 of Set 2 --- Tunitas Creek Beach
# Processing Record 27 of Set 2 --- San Gregorio Private Beach
# Processing Record 28 of Set 2 --- San Gregorio State Beach
# Processing Record 29 of Set 2 --- Pomponio State Beach
# Processing Record 30 of Set 2 --- Pescadero State Beach
# Processing Record 1 of Set 3 --- Bean Hollow State Beach
# Processing Record 2 of Set 3 --- Pigeon Point Beach
# Processing Record 3 of Set 3 --- Gazos Creek State Beach
# Processing Record 4 of Set 3 --- Año Nuevo State Park
# Processing Record 5 of Set 3 --- New Brighton State Beach
# Processing Record 6 of Set 3 --- Capitola State Beach
# Processing Record 7 of Set 3 --- Seacliff State Beach
# Processing Record 8 of Set 3 --- Santa Cruz Beach
# Processing Record 9 of Set 3 --- Twin Lakes State Beach
# Processing Record 10 of Set 3 --- Lighthouse Field State Beach
# Processing Record 11 of Set 3 --- Natural Bridges State Beach
# Processing Record 12 of Set 3 --- Manresa State Beach
# Processing Record 13 of Set 3 --- Sunset State Beach
# Processing Record 14 of Set 3 --- Zmudowski State Beach
# Processing Record 15 of Set 3 --- Moss Landing State Beach
# Processing Record 16 of Set 3 --- Salinas River State Beach
# Processing Record 17 of Set 3 --- Marina State Beach
# Processing Record 18 of Set 3 --- Asilomar State Beach
# Processing Record 19 of Set 3 --- Monterey State Beach
# Processing Record 20 of Set 3 --- Pebble Beach
# Processing Record 21 of Set 3 --- Carmel River State Beach
# Processing Record 22 of Set 3 --- Point Sur Lightstation State Historic Park
# Processing Record 23 of Set 3 --- Sand Dollar Beach
# Processing Record 24 of Set 3 --- William Randolph Hearst Memorial State Beach
# Processing Record 25 of Set 3 --- Cayucos State Beach
# Processing Record 26 of Set 3 --- Morro Strand State Beach
# Processing Record 27 of Set 3 --- Morro Rock Beach
# Processing Record 28 of Set 3 --- Ávila Beach
# Processing Record 29 of Set 3 --- Shell Beach
# Processing Record 30 of Set 3 --- Pismo Beach Pier
# Processing Record 1 of Set 4 --- Rancho Guadalupe Dunes County Park
# Processing Record 2 of Set 4 --- Point Sal State Beach
# Processing Record 3 of Set 4 --- Surf Beach
# Processing Record 4 of Set 4 --- Jalama Beach County Park
# Processing Record 5 of Set 4 --- Gaviota State Park
# Processing Record 6 of Set 4 --- Refugio State Beach
# Processing Record 7 of Set 4 --- El Capitán State Beach
# Processing Record 8 of Set 4 --- Sands Beach
# Processing Record 9 of Set 4 --- Summerland Beach
# Processing Record 10 of Set 4 --- Butterfly Beach
# Processing Record 11 of Set 4 --- Goleta Beach Park
# Processing Record 12 of Set 4 --- East Beach
# Processing Record 13 of Set 4 --- West Beach
# Processing Record 14 of Set 4 --- Arroyo Burro Beach
# Processing Record 15 of Set 4 --- Leadbetter Beach
# Processing Record 16 of Set 4 --- Carpinteria State Beach
# Processing Record 17 of Set 4 --- Rincon Beach Park
# Processing Record 18 of Set 4 --- Emma Wood State Beach
# Processing Record 19 of Set 4 --- San Buenaventura State Beach
# Processing Record 20 of Set 4 --- McGrath State Beach
# Processing Record 21 of Set 4 --- Oxnard Beach Park
# Processing Record 22 of Set 4 --- Silver Strand Beach
# Processing Record 23 of Set 4 --- Port Hueneme Beach Park
# Processing Record 24 of Set 4 --- Topanga Beach
# Processing Record 25 of Set 4 --- County Line Beach
# Processing Record 26 of Set 4 --- Leo Carrillo State Park
# Processing Record 27 of Set 4 --- El Pescador State Beach
# Processing Record 28 of Set 4 --- La Piedra State Beach
# Processing Record 29 of Set 4 --- Robert Meyer Memorial State Beach
# Processing Record 30 of Set 4 --- Broad Beach
# Processing Record 1 of Set 5 --- Will Rogers State Beach
# Processing Record 2 of Set 5 --- Lechuza Beach
# Processing Record 3 of Set 5 --- Malibu Lagoon State Beach
# Processing Record 4 of Set 5 --- Palisades Park
# Processing Record 5 of Set 5 --- Zuma Beach County Park
# Processing Record 6 of Set 5 --- Santa Monica State Beach
# Processing Record 7 of Set 5 --- Point Dume State Beach
# Processing Record 8 of Set 5 --- Venice Beach
# Processing Record 9 of Set 5 --- Playa Del Rey
# Processing Record 10 of Set 5 --- Dockweiler Beach
# Processing Record 11 of Set 5 --- El Segundo Beach
# Processing Record 12 of Set 5 --- El Porto Beach
# Processing Record 13 of Set 5 --- Manhattan Beach Pier
# Processing Record 14 of Set 5 --- Redondo Beach Pier
# Processing Record 15 of Set 5 --- Hermosa Beach Pier
# Processing Record 16 of Set 5 --- Torrance County Beach
# Processing Record 17 of Set 5 --- RAT Beach
# Processing Record 18 of Set 5 --- Seal Beach
# Processing Record 19 of Set 5 --- Royal Palms Beach Park
# Processing Record 20 of Set 5 --- Cabrillo Beach
# Processing Record 21 of Set 5 --- Bolsa Chica State Beach
# Processing Record 22 of Set 5 --- Huntington City Beach
# Processing Record 23 of Set 5 --- Huntington State Beach
# Processing Record 24 of Set 5 --- Santa Ana River County Beach
# Processing Record 25 of Set 5 --- Newport Beach Municipal Beach
# Processing Record 26 of Set 5 --- Balboa Beach
# Processing Record 27 of Set 5 --- The Wedge (Newport Beach)
# Processing Record 28 of Set 5 --- Corona del Mar State Beach
# Processing Record 29 of Set 5 --- Little Corona del Mar Beach
# Processing Record 30 of Set 5 --- Crystal Cove State Park
# Processing Record 1 of Set 6 --- Crescent Bay Point Park
# Processing Record 2 of Set 6 --- Shaw's Cove
# Processing Record 3 of Set 6 --- Diver's Cove
# Processing Record 4 of Set 6 --- Picnic Beach
# Processing Record 5 of Set 6 --- Rockpile Beach
# Processing Record 6 of Set 6 --- Laguna Beach
# Processing Record 7 of Set 6 --- Main Beach
# Processing Record 8 of Set 6 --- Brooks Street Beach
# Processing Record 9 of Set 6 --- Victoria Beach
# Processing Record 10 of Set 6 --- Aliso Beach
# Processing Record 11 of Set 6 --- West Street Beach
# Processing Record 12 of Set 6 --- 1,000 Steps Beach
# Processing Record 13 of Set 6 --- Salt Creek County Beach
# Processing Record 14 of Set 6 --- Doheny State Beach
# Processing Record 15 of Set 6 --- Capistrano Beach Park
# Processing Record 16 of Set 6 --- Beach State Park
# Processing Record 17 of Set 6 --- Poche Beach
# Processing Record 18 of Set 6 --- San Clemente City Beach
# Processing Record 19 of Set 6 --- San Clemente State Beach
# Processing Record 20 of Set 6 --- San Onofre State Beach
# Processing Record 21 of Set 6 --- Del Mar Beach, Camp Pendleton
# Processing Record 22 of Set 6 --- Oceanside Harbor Beach
# Processing Record 23 of Set 6 --- Oceanside City Beach
# Processing Record 24 of Set 6 --- Buccaneer Beach, Oceanside
# Processing Record 25 of Set 6 --- South Oceanside Beach (Cassidy Street)
# Processing Record 26 of Set 6 --- Saint Malo Beach
# Processing Record 27 of Set 6 --- Carlsbad City Beach
# Processing Record 28 of Set 6 --- Carlsbad State Beach
# Processing Record 29 of Set 6 --- Terra Mar Point
# Processing Record 30 of Set 6 --- Ponto Beach
# Processing Record 1 of Set 7 --- South Carlsbad State Beach
# Processing Record 2 of Set 7 --- Grandview
# Processing Record 3 of Set 7 --- Beacon's Beach
# Processing Record 4 of Set 7 --- Stone Steps Beach
# Processing Record 5 of Set 7 --- Moonlight Beach
# Processing Record 6 of Set 7 --- D Street Viewpoint
# Processing Record 7 of Set 7 --- Swamis
# Processing Record 8 of Set 7 --- San Elijo State Beach
# Processing Record 9 of Set 7 --- Cardiff State Beach
# Processing Record 10 of Set 7 --- Tide Beach Park
# Processing Record 11 of Set 7 --- Fletcher Cove Park
# Processing Record 12 of Set 7 --- Seascape Surf
# Processing Record 13 of Set 7 --- Del Mar City Beach
# Processing Record 14 of Set 7 --- Torrey Pines State Beach
# Processing Record 15 of Set 7 --- Black's Beach
# Processing Record 16 of Set 7 --- La Jolla Shores
# Processing Record 17 of Set 7 --- La Jolla Cove
# Processing Record 18 of Set 7 --- Marine Street Beach
# Processing Record 19 of Set 7 --- Windansea Beach
# Processing Record 20 of Set 7 --- Tourmaline Surfing Park
# Processing Record 21 of Set 7 --- Pacific Beach
# Processing Record 22 of Set 7 --- Mission Beach
# Processing Record 23 of Set 7 --- Ocean Beach City Beach
# Processing Record 24 of Set 7 --- Coronado Municipal Beach
# Processing Record 25 of Set 7 --- Silver Strand State Beach
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert dictionaries into a Pandas DF
beach_data_df = pd.DataFrame(beach_data)
beach_data_df.tail(20)
# Out:
#                     Beach_Name   Latitude   Longitude   Sunrise    Sunset  \
# 185         D Street Viewpoint  33.045704 -117.297428  06:28 AM  04:44 PM
# 186                     Swamis  33.035028 -117.292920  06:28 AM  04:44 PM
# 187      San Elijo State Beach  33.022579 -117.284252  06:28 AM  04:44 PM
# 188        Cardiff State Beach  33.010506 -117.279630  06:28 AM  04:44 PM
# 189            Tide Beach Park  32.996866 -117.276454  06:28 AM  04:44 PM
# 190         Fletcher Cove Park  32.990891 -117.275296  06:28 AM  04:44 PM
# 191              Seascape Surf  32.985676 -117.272912  06:28 AM  04:44 PM
# 192         Del Mar City Beach  32.976959 -117.269502  06:28 AM  04:44 PM
# 193   Torrey Pines State Beach  32.937781 -117.261734  06:27 AM  04:44 PM
# 194              Black's Beach  32.891473 -117.255989  06:27 AM  04:44 PM
# 195            La Jolla Shores  32.885635 -117.253542  06:27 AM  04:44 PM
# 196              La Jolla Cove  32.850382 -117.273024  06:27 AM  04:44 PM
# 197        Marine Street Beach  32.837856 -117.281684  06:27 AM  04:44 PM
# 198            Windansea Beach  32.831230 -117.281363  06:27 AM  04:44 PM
# 199    Tourmaline Surfing Park  32.805459 -117.262537  06:27 AM  04:44 PM
# 200              Pacific Beach  32.793934 -117.256811  06:27 AM  04:44 PM
# 201              Mission Beach  32.773040 -117.251710  06:27 AM  04:44 PM
# 202     Ocean Beach City Beach  32.741633 -117.254458  06:27 AM  04:44 PM
# 203   Coronado Municipal Beach  32.689464 -117.186835  06:27 AM  04:44 PM
# 204  Silver Strand State Beach  32.634664 -117.141993  06:26 AM  04:43 PM
#
#     Weather_Description Temperature Water_Temperature Cloud_Cover Wind_Speed  \
# 185               Clear          63                58           0          7
# 186               Clear          63                58           0          7
# 187               Clear          63                58           0          7
# 188               Clear          63                58           0          7
# 189               Clear          63                58           0          7
# 190               Clear          63                58           0          7
# 191               Clear          63                58           0          7
# 192               Clear          63                58           0          7
# 193               Clear          63                58           0          7
# 194               Clear          63                58           0          7
# 195               Clear          63                58           0          7
# 196               Clear          63                58           0          7
# 197               Clear          63                58           0          7
# 198               Clear          63                58           0          7
# 199               Clear          63                58           0          7
# 200               Clear          63                58           0          7
# 201               Clear          63                58           0          7
# 202               Clear          63                58           0          7
# 203               Clear          63                58           0          8
# 204               Clear          63                58           0          8
#
#     Wave_Height
# 185         3.6
# 186         3.6
# 187         3.6
# 188         3.6
# 189         3.6
# 190         3.6
# 191         3.6
# 192         3.6
# 193         3.6
# 194         3.6
# 195         3.6
# 196         3.6
# 197         3.6
# 198         3.6
# 199         3.6
# 200         3.6
# 201         3.6
# 202         3.6
# 203         3.9
# 204         3.9

# %%
# Create the output file (CSV).
#output_data_file = "beach_data_df.csv"

# Export the beach_data_df into a CSV.
#beach_data_df.to_csv(output_data_file, index_label="beach_id")

# %%
#beach_data_df = pd.read_csv("beaches_data.csv")
#beach_data_df.head()

# %%
# Renamed "Unnamed: 0" column and set it as the index
#beach_data_df = beach_data_df.rename(columns={'Unnamed: 0': ''})
#beach_data_df = beach_data_df.set_index('Beach_ID')
#beach_data_df.head()

# %%
wave_height_bins = [0, 3, 9, 12]
wave_size = ["Small (<4)", "Medium (4-9)", "Large (10-12)"]


# Categorize based on the bins.
beach_data_df["Wave_Size"] = pd.cut(beach_data_df["Wave_Height"], wave_height_bins, labels=wave_size)
beach_data_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 6>()
#       2 wave_size = ["Small (<4)", "Medium (4-9)", "Large (10-12)"]
#       5 # Categorize based on the bins.
# ----> 6 beach_data_df["Wave_Size"] = pd.cut(beach_data_df["Wave_Height"], wave_height_bins, labels=wave_size)
#       7 beach_data_df
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py:292, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     289     if (np.diff(bins.astype("float64")) < 0).any():
#     290         raise ValueError("bins must increase monotonically.")
# --> 292 fac, bins = _bins_to_cuts(
#     293     x,
#     294     bins,
#     295     right=right,
#     296     labels=labels,
#     297     precision=precision,
#     298     include_lowest=include_lowest,
#     299     dtype=dtype,
#     300     duplicates=duplicates,
#     301     ordered=ordered,
#     302 )
#     304 return _postprocess_for_cut(fac, bins, retbins, dtype, original)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py:427, in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     424         bins = unique_bins
#     426 side: Literal["left", "right"] = "left" if right else "right"
# --> 427 ids = ensure_platform_int(bins.searchsorted(x, side=side))
#     429 if include_lowest:
#     430     ids[np.asarray(x) == bins[0]] = 1
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
# Create the output file (CSV).
#output_data_file = "beach_data_df.csv"

# Export the beaches_data into a CSV.
#beach_data_df.to_csv(output_data_file, index_label="Beach_ID")
